# %% [markdown]
# # Unitree Hermes Agent Safety Lab
#
# This Colab installs or checks Hermes Agent, clones selected Unitree repositories, and produces read-only runbook, safety, contribution, and log-triage artifacts. It does not control a physical Unitree robot from Colab.
#
# Use a clean runtime before sharing results. If you want Hermes to execute one model-backed prompt, set `RUN_HERMES_AGENT = True` in the runner after adding a provider key through Colab secrets.

# %%
import urllib.request
exec(urllib.request.urlopen("https://raw.githubusercontent.com/zack-dev-cm/unitree-g1-colab-ik/main/notebooks/run_unitree_hermes_agent_lab.py?cachebust=20260606-final-report").read().decode("utf-8"))
